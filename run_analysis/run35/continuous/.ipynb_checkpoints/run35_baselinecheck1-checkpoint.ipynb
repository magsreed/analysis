# %%
import detprocess as dp
import numpy as np
import pandas as pd
from pprint import pprint
import astropy
import vaex as vx
from matplotlib import pyplot as plt
from detanalysis import Analyzer, Semiautocut, ScatterPlotter 
import matplotlib as mpl
import qetpy
import scipy
from scipy.optimize import curve_fit
from scipy.stats import skewnorm
from scipy import stats, optimize, interpolate
import scipy.optimize as opt
from scipy.special import erf
import math
from astropy import units as U
import detanalysis.func as cut
mpl.rcParams['figure.figsize'] = [10, 6.5]
from pytesdaq.io.hdf5 import H5Reader,H5Writer

import warnings
warnings.filterwarnings('ignore')
# Out:
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/maggie_reed/.local/lib/python3.6/site-packages/paramiko/transport.py:32: CryptographyDeprecationWarning: Python 3.6 is no longer supported by the Python core team. Therefore, support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.6.
#   from cryptography.hazmat.backends import default_backend
# /usr/lib64/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %% [markdown]
# # Setup

# %%
fs = 1.25e6 #sample_rate [hz]
tracelength = 5e-3 #[s]

# %%
basedir = '/home/maggie_reed/analysis/run32/figs'

# %%
#afternoon 2 hour set
myanalyzer = Analyzer('/sdata2/runs/run32/processed/continuous_I2_D20230828_T153741/feature_I2_D20230829_T143111',series=None)
#evening 2 hour set
myanalyzer2 = Analyzer('/sdata2/runs/run32/processed/continuous_I2_D20230828_T225110/feature_I2_D20230829_T143626',series=None)

# %%
myanalyzer.add_feature((myanalyzer.df.event_time - myanalyzer.df.event_time.min())/60, 'timesincestart',overwrite=True)
myanalyzer2.add_feature((myanalyzer2.df.event_time - myanalyzer2.df.event_time.min())/60, 'timesincestart',overwrite=True)

# %%
myanalyzer.df.head()
# Out:
#   #    amp_of1x1_unconstrained_Melange025pcLeft    amp_of1x1_unconstrained_Melange025pcRight    amp_of1x1_unconstrained_Melange1pc1ch    amp_of1x1_unconstrained_Melange4pc1ch    baseline_Melange025pcLeft    baseline_Melange025pcRight    baseline_Melange1pc1ch    baseline_Melange4pc1ch    baseline_end_Melange025pcLeft    baseline_end_Melange025pcRight    baseline_end_Melange1pc1ch    baseline_end_Melange4pc1ch    chi2_of1x1_unconstrained_Melange025pcLeft    chi2_of1x1_unconstrained_Melange025pcRight    chi2_of1x1_unconstrained_Melange1pc1ch    chi2_of1x1_unconstrained_Melange4pc1ch    data_type    dump_number    event_number    event_time    fridge_run_number    fridge_run_start_time  group_name                         group_start_time    integral_Melange025pcLeft    integral_Melange025pcRight    integral_Melange1pc1ch    integral_Melange4pc1ch    lowchi2_of1x1_unconstrained_Melange025pcLeft    lowchi2_of1x1_unconstrained_Melange025pcRight    lowchi2_of1x1_unconstrained_Melange1pc1ch    lowchi2_of1x1_unconstrained_Melange4pc1ch    maximum_Melange025pcLeft    maximum_Melange025pcRight    maximum_Melange1pc1ch    maximum_Melange4pc1ch    minimum_Melange025pcLeft    minimum_Melange025pcRight    minimum_Melange1pc1ch    minimum_Melange4pc1ch    output_gain_Melange025pcLeft    output_gain_Melange025pcRight    output_gain_Melange1pc1ch    output_gain_Melange4pc1ch    processing_id    series_number    series_start_time    t0_of1x1_unconstrained_Melange025pcLeft    t0_of1x1_unconstrained_Melange025pcRight    t0_of1x1_unconstrained_Melange1pc1ch    t0_of1x1_unconstrained_Melange4pc1ch    tes_bias_Melange025pcLeft    tes_bias_Melange025pcRight    tes_bias_Melange1pc1ch    tes_bias_Melange4pc1ch    trigger_index  trigger_prod_group_name         trigger_prod_id    trigger_time    trigger_type    timesincestart
)
#''';

# %% [markdown]
# ## Melange025pcLeft

# %%
fig,ax  = myanalyzer.heatmap('timesincestart',
                             'baseline_Melange025pcLeft',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange025pcLeft',
                             title='Melange025pcLeft Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/25pcleft_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# ## Melange1pc1ch

# %%
fig,ax  = myanalyzer.heatmap('timesincestart',
                             'baseline_Melange1pc1ch',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange1pc1ch',
                             title='Melange1pc1ch Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/1pc_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# ## Melange4pc1ch

# %%
fig,ax  = myanalyzer.heatmap('timesincestart',
                             'baseline_Melange4pc1ch',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange4pc1ch',
                             title='Melange4pc1ch Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/4pc_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# # Baseline, Evening Set

# %% [markdown]
# ## Melange025pcRight

# %%
fig,ax  = myanalyzer2.heatmap('timesincestart',
                             'baseline_Melange025pcRight',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange025pcRight',
                             title='Melange025pcRight Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/evening_25pcright_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# ## Melange025pcLeft

# %%
fig,ax  = myanalyzer2.heatmap('timesincestart',
                             'baseline_Melange025pcLeft',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange025pcLeft',
                             title='Melange025pcLeft Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/evening_25pcleft_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# ## Melange1pc1ch

# %%
fig,ax  = myanalyzer2.heatmap('timesincestart',
                             'baseline_Melange1pc1ch',
                            # ylimits = [-1.44e-6, -1.4e-6],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange1pc1ch',
                             title='Melange1pc1ch Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/evening_1pc_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';

# %% [markdown]
# ## Melange4pc1ch

# %%
fig,ax  = myanalyzer2.heatmap('timesincestart',
                             'baseline_Melange4pc1ch',
                             ylimits = [-5e-7, -4e-7],
                             xlabel='Time Since Run Start [m]', ylabel='Baseline of Melange4pc1ch',
                             title='Melange4pc1ch Baseline vs Time: no cuts',)
fig.tight_layout()
'''
fig.savefig(
    basedir+'/evening_4pc_blvt_nc.png',
    dpi=500,
    facecolor='none',
)
#''';
